# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52136/AIML_2303A52136/blob/main/Experiment_1_of_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualization of data using matplotlab,pyplots, pack-ages
# Giving the age in years ,height in meters,weight in kgs

# %%
import matplotlib.pyplot as mpt
people = ["kiran","arun","vijay","varun"]
age = [25,30,35,40]
height = [145,151,165,173]
weight = [45,55,65,75]
mpt.scatter(weight,height,color='red')
mpt.title("Scatter plot graph on the relation between height and weight")
mpt.xlabel("Height in meters")
mpt.ylabel("Weight in kgs")
mpt.show()
mpt.figure(figsize=(15,3))

# %% [markdown]
# justification:
# This scatter plot shows the relationship between Height and weight.

# %% [markdown]
# BAR CHART

# %%
people = ["kiran","arun","vijay","varun"]
height = [145,151,165,173]
import matplotlib.pyplot as mpt
mpt.bar(people,height,color='blue',width=0.5)
mpt.title("Bar chart on the relation between age and height")
mpt.xlabel("age in years")
mpt.ylabel("height in meters")
mpt.show()
mpt.figure(figsize=(16,4))

# %% [markdown]
# Justification : The bar chart shows the relation between people and height

# %% [markdown]
# HISTOGRAM

# %%
import matplotlib.pyplot as plt
age = [25,30,35,40]

weight = [45,55,65,75]
plt.hist(age, bins=5, alpha=0.3)
plt.hist(weight, bins=5, alpha=0.2)
plt.xlabel('Age in years')
plt.ylabel('Weight in kgs')
plt.title('Histogram of age and Weight')
plt.show()
